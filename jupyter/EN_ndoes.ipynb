# %%
import numpy as np
s = np.random.poisson(2, 100)

# %%
s
# Out:
# array([2, 2, 3, 4, 1, 2, 1, 5, 1, 2, 0, 2, 2, 1, 3, 3, 1, 2, 2, 2, 0, 3,
#        0, 3, 0, 3, 1, 2, 1, 3, 2, 1, 5, 1, 2, 3, 3, 4, 1, 4, 5, 3, 2, 5,
#        2, 2, 2, 2, 4, 3, 1, 4, 0, 3, 0, 1, 1, 2, 3, 1, 6, 2, 2, 6, 0, 0,
#        1, 3, 1, 2, 2, 4, 3, 2, 2, 3, 0, 1, 3, 0, 2, 2, 2, 0, 1, 4, 3, 2,
#        1, 3, 0, 0, 0, 1, 3, 3, 1, 1, 1, 2])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(s)
plt.show()

# %%
import random_timestamp

# %%
import random
f = []
for i in range(100):
    f.append(random.randint(1,10))
plt.plot(f)
